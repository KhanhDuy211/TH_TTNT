# %% [markdown]
# <a href="https://colab.research.google.com/github/KhanhDuy211/TH_TTNT_Tuan3/blob/main/Minimax%26Alpha_Beta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- THUẬT GIẢI MINIMAX ÁP DỤNG VÀ BÀI TOÁN TICTACTOE --- #

import copy
import math
import random
import numpy

X = "X"
O = "O"
EMPTY = None
user = None
ai = None

def initial_state():
  """
  Returns starting state of the board.
  """
  return [ [ EMPTY, EMPTY, EMPTY],
             EMPTY, EMPTY, EMPTY],
             EMPTY, EMPTY, EMPTY]]

def player(board):
